# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from package.noncentroid import clusterize
from sklearn.cluster import KMeans
from pac

# %% [markdown]
# # Extract data

# %%
df_objects = pd.read_csv('data/objects.csv')

objects = df_objects[['x', 'y']].values
weights = df_objects['weight'].values
original_clusters = df_objects['cluster'].values

df_objects
# Out:
#              x         y  weight  cluster
# 0    -8.672670 -2.612933      18        2
# 1   -10.571752 -1.952086      28        2
# 2    -3.672195  8.881163       4        1
# 3    -3.097604 -4.866545      29        3
# 4    -3.850307  8.290241      24        1
# ..         ...       ...     ...      ...
# 115  -2.144920 -5.172657      35        3
# 116  -2.327743 -4.880652      19        3
# 117  -2.594274 -6.487214      18        3
# 118  -8.311321 -0.587080       4        2
# 119  -9.463336 -2.499161       1        2
#
# [120 rows x 4 columns]

# %%
distances = pd.read_csv('data/distances.csv', header=None).values

# %%
clusters = np.unique(original_clusters)
cluster_colors = np.random.random(size=(len(clusters), 3))*0.8 + 0.1

# %% [markdown]
# # Noncentroid Clusterization

# %%
labels = clusterize(dists=distances, weights=weights, n_clusters=4)
my_clusters = np.argmax(labels, axis=1)

# %%
pd.DataFrame({'Original' : original_clusters, 'Predicted': my_clusters})
# Out:
#      Original  Predicted
# 0           2          3
# 1           2          3
# 2           1          2
# 3           3          1
# 4           1          2
# ..        ...        ...
# 115         3          3
# 116         3          1
# 117         3          2
# 118         2          1
# 119         2          0
#
# [120 rows x 2 columns]

# %%
plt.figure(figsize=(10, 10))

for cluster in clusters:
    cluster_objects_original = objects[original_clusters == cluster]
    cluster_objects_predicted = objects[my_clusters == cluster]
    
    x_or = cluster_objects_original[:, 0]
    y_or = cluster_objects_original[:, 1]
    x_pr = cluster_objects_predicted[:, 0]
    y_pr = cluster_objects_predicted[:, 1]
    
    col = cluster_colors[cluster]
    plt.scatter(x_or, y_or, linewidth=12, color='white', edgecolors=col, zorder=0, label='Cluster '+str(cluster)+' original')
    plt.scatter(x_or, y_or, linewidth=5, color='white', zorder=1)
    plt.scatter(x_pr, y_pr, linewidth=2, color=col, zorder=2, label='Cluster '+str(cluster)+' by clusterize')

plt.legend()
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame({'Original' : original_clusters})
for cluster in clusters:
    df['P(cluster is ' + str(cluster) + ')'] = labels[:, cluster]
df
# Out:
#      Original  P(cluster is 0)  P(cluster is 1)  P(cluster is 2)  \
# 0           2         0.164560         0.354212         0.125962
# 1           2         0.187893         0.296589         0.187074
# 2           1         0.233278         0.051508         0.424665
# 3           3         0.174364         0.406471         0.394110
# 4           1         0.297540         0.214979         0.333449
# ..        ...              ...              ...              ...
# 115         3         0.057396         0.022278         0.384609
# 116         3         0.137676         0.387876         0.369572
# 117         3         0.110973         0.202828         0.436169
# 118         2         0.317035         0.334568         0.306383
# 119         2         0.548162         0.087200         0.182707
#
#      P(cluster is 3)
# 0           0.355267
# 1           0.328444
# 2           0.290549
# 3           0.025055
# 4           0.154032
# ..               ...
# 115         0.535716
# 116         0.104877
# 117         0.250030
# 118         0.042014
# 119         0.181931
#
# [120 rows x 5 columns]

# %% [markdown]
# ## Sklearn KMeans

# %% [markdown]
# ## without weights

# %%
model = KMeans(n_clusters=4)
model.fit(objects)
predicted_clusters = model.predict(objects)

# %%
pd.DataFrame({'Original' : original_clusters, 'Predicted': predicted_clusters})
# Out:
#      Original  Predicted
# 0           2          2
# 1           2          2
# 2           1          3
# 3           3          1
# 4           1          3
# ..        ...        ...
# 115         3          1
# 116         3          1
# 117         3          1
# 118         2          2
# 119         2          2
#
# [120 rows x 2 columns]

# %%
plt.figure(figsize=(10, 10))

for cluster in clusters:
    cluster_objects_original = objects[original_clusters == cluster]
    cluster_objects_predicted = objects[predicted_clusters == cluster]
    
    x_or = cluster_objects_original[:, 0]
    y_or = cluster_objects_original[:, 1]
    x_pr = cluster_objects_predicted[:, 0]
    y_pr = cluster_objects_predicted[:, 1]
    
    col = cluster_colors[cluster]
    plt.scatter(x_or, y_or, linewidth=12, color='white', edgecolors=col, zorder=0, label='Cluster '+str(cluster)+' original')
    plt.scatter(x_or, y_or, linewidth=5, color='white', zorder=1)
    plt.scatter(x_pr, y_pr, linewidth=2, color=col, zorder=2, label='Cluster '+str(cluster)+' by nonweighted KMeans')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## with weights

# %%
model = KMeans(n_clusters=4)
model.fit(objects, sample_weight=weights)
predicted_clusters = model.predict(objects)

# %%
plt.figure(figsize=(10, 10))

for cluster in clusters:
    cluster_objects_original = objects[original_clusters == cluster]
    cluster_objects_predicted = objects[predicted_clusters == cluster]
    
    x_or = cluster_objects_original[:, 0]
    y_or = cluster_objects_original[:, 1]
    x_pr = cluster_objects_predicted[:, 0]
    y_pr = cluster_objects_predicted[:, 1]
    
    col = cluster_colors[cluster]
    plt.scatter(x_or, y_or, linewidth=12, color='white', edgecolors=col, zorder=0, label='Cluster '+str(cluster)+' original')
    plt.scatter(x_or, y_or, linewidth=5, color='white', zorder=1)
    plt.scatter(x_pr, y_pr, linewidth=2, color=col, zorder=2, label='Cluster '+str(cluster)+' by weighted KMeans')

plt.legend()
plt.grid(True)
plt.show()
